# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import normalize
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import

# %%
df=pd.read_csv('letter-recognition.csv',index_col=False)

# %%
df.rename(columns={'lettr':'Letter'},inplace=True)

# %%
df
# Out:
#       Letter  x-box  y-box  width  high   onpix  x-bar  y-bar  x2ba  y2bar  \
# 0          T      2      8      3      5      1      8     13     0      6
# 1          I      5     12      3      7      2     10      5     5      4
# 2          D      4     11      6      8      6     10      6     2      6
# 3          N      7     11      6      6      3      5      9     4      6
# 4          G      2      1      3      1      1      8      6     6      6
# ...      ...    ...    ...    ...    ...    ...    ...    ...   ...    ...
# 19995      D      2      2      3      3      2      7      7     7      6
# 19996      C      7     10      8      8      4      4      8     6      9
# 19997      T      6      9      6      7      5      6     11     3      7
# 19998      S      2      3      4      2      1      8      7     2      6
# 19999      A      4      9      6      6      2      9      5     3      1
#
#        xybar  x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# ...

# %%
Y=df.iloc[:,0]

# %%
df1=df.drop('Letter',axis=1)

# %%
df1
# Out:
#        x-box  y-box  width  high   onpix  x-bar  y-bar  x2ba  y2bar  xybar  \
# 0          2      8      3      5      1      8     13     0      6      6
# 1          5     12      3      7      2     10      5     5      4     13
# 2          4     11      6      8      6     10      6     2      6     10
# 3          7     11      6      6      3      5      9     4      6      4
# 4          2      1      3      1      1      8      6     6      6      6
# ...      ...    ...    ...    ...    ...    ...    ...   ...    ...    ...
# 19995      2      2      3      3      2      7      7     7      6      6
# 19996      7     10      8      8      4      4      8     6      9     12
# 19997      6      9      6      7      5      6     11     3      7     11
# 19998      2      3      4      2      1      8      7     2      6     10
# 19999      4      9      6      6      2      9      5     3      1      8
#
#        x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# ...

# %%
X=df1

# %%
X.shape
# Out:
# (20000, 16)

# %%
X1 = normalize(X)
X2 = pd.DataFrame(X1, columns=X.columns)
print(X2)
# Out:
#           x-box     y-box     width     high      onpix     x-bar     y-bar  \
# 0      0.075593  0.302372  0.113389  0.188982  0.037796  0.302372  0.491354
# 1      0.172516  0.414039  0.103510  0.241523  0.069007  0.345033  0.172516
# 2      0.145575  0.400331  0.218362  0.291150  0.218362  0.363937  0.218362
# 3      0.256460  0.403009  0.219823  0.219823  0.109911  0.183186  0.329734
# 4      0.088999  0.044499  0.133498  0.044499  0.044499  0.355995  0.266996
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.096787  0.096787  0.145180  0.145180  0.096787  0.338754  0.338754
# 19996  0.218430  0.312043  0.249635  0.249635  0.124817  0.124817  0.249635
# 19997  0.207390  0.311086  0.207390  0.241955  0.172825  0.207390  0.380216
# 19998  0.084667  0.127000  0.169334  0.084667  0.042333  0.338667  0.296334
# 19999  0.172292  0.387657  0.258438  0.258438  0.086146  0.387657  0.215365
#
# ...

# %%
X=X2

# %%
Samples=[]
Num=10
for i in range(Num):
    X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=42)
    Samples.append((X_train, X_test, y_train, y_test))

# %%
Samples
# Out:
# [(          x-box     y-box     width     high      onpix     x-bar     y-bar  \
#   17218  0.199667  0.366057  0.232945  0.299501  0.099834  0.232945  0.232945
#   15188  0.079243  0.277350  0.118864  0.158486  0.079243  0.198107  0.396214
#   11295  0.293080  0.325645  0.293080  0.260516  0.162822  0.162822  0.227951
#   19772  0.182940  0.182940  0.182940  0.256117  0.109764  0.256117  0.292705
#   13072  0.106938  0.178231  0.142585  0.285169  0.071292  0.000000  0.427754
#   ...         ...       ...       ...       ...       ...       ...       ...
#   11284  0.186598  0.410516  0.149279  0.223918  0.111959  0.261238  0.261238
#   11964  0.121666  0.283887  0.202777  0.202777  0.162221  0.364998  0.446109
#   5390   0.126773  0.169031  0.253546  0.126773  0.084515  0.380319  0.253546
#   860    0.114374  0.304997  0.152499  0.228748  0.076249  0.266872  0.304997
#   15795  0.045038  0.135113  0.090075  0.090075  0.045038  0.450377  0.315264
#
# ...

# %%
df3 = pd.DataFrame(columns=['Sample', 'Best Accuracy', 'Best Kernel', 'Best Nu', 'Best Epsilon'])

# %%
kernel=['linear','rbf','sigmoid','poly']
def SVM_function(kernal,gamm,C,samples,j):
    SVM=svm.SVC(kernel=kernal,gamma=gamm,C=C,max_iter=1000)
    X_train,X_test,y_train,y_test=samples[j]
    SVM.fit(X_train,y_train)
    y_pred=SVM.predict(X_test)
    return accuracy_score(y_pred,y_test)

# %%
def SVM_function_1(kernal,gamm,C,samples,j):
    SVM=svm.SVC(kernel=kernal,gamma=gamm,C=C,max_iter=1000)
    X_train,X_test,y_train,y_test=samples[j]
    SVM.fit(X_train,y_train)
    y_pred=SVM.predict(X_test)
    acc = []
    for j in range(1, 1001):
        acc.append(clf.score(X_test, y_test))
        clf.decision_function(X_train)
    return acc

# %%
def SampleKern():
    k=random.choice(kernel)
    return k

# %%
bestAccuracy=0
bestKernel=""
bestNu=0
bestEpsilon=0
for i in range(0,len((Samples))):
    #print(i)
    k=SampleKern()
    C = random.uniform(0, 10)
    gamma =random.uniform(0, 10)
    score = SVM_function(k, gamma,C,Samples,i)
    #acc=SVM_function_1(k, gamma,C,Samples,i)
    #print("sample accuracy: ",score)
    #print("Nu: ",C)
    #print('Gamma: ',gamma)
    #print('------------------------------')
    if score>bestAccuracy:
        bestAccuracy=round(score, 2)
        bestNu = round(C, 2)
        bestEpsilon = round(gamma, 2)
        bestKernel=k
    #if i == np.argmax(bestAccuracy):
        #plt.plot(acc)
        #plt.xlabel('Iterations')
        #plt.ylabel('Accuracy')
        #plt.title('Convergence Graph for Sample with Highest Accuracy')
        #plt.show()
    
    #print('Best Accuracy = ', bestAccuracy, 'Best Kernel = ', bestKernel, 'Best Nu = ', bestNu, 'Best Epsilon = ', bestEpsilon)
    df3.loc[i]=[i+1,bestAccuracy,bestKernel,bestNu,bestEpsilon]

# %%
df3
# Out:
#    Sample  Best Accuracy Best Kernel  Best Nu  Best Epsilon
# 0       1           0.78      linear     1.21          6.92
# 1       2           0.78      linear     1.21          6.92
# 2       3           0.86         rbf     8.19          0.71
# 3       4           0.88         rbf     2.08          2.05
# 4       5           0.88         rbf     2.08          2.05
# 5       6           0.88         rbf     2.08          2.05
# 6       7           0.88         rbf     2.08          2.05
# 7       8           0.88         rbf     2.08          2.05
# 8       9           0.88         rbf     2.08          2.05
# 9      10           0.95        poly     9.61          2.96

# %%
Xax=list(range(0,1100,100))

# %%
Xax
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# %%
Xax1=np.array(Xax[1:])

# %%
Yay=df3.loc[:,'Best Accuracy']

# %%
Yay1=np.array(Yay)

# %%
plt.figure(figsize=(10,7))
plt.plot(Xax1,Yay1)
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.title('Convergence Graph')
plt.show()
